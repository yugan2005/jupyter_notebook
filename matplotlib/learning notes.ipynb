# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

# %%
plt.plot([1,2,3])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.ioff();
plt.title('test2');
plt.xlabel('have fun2');

# %%
plt.ion()

# %%
import matplotlib as mpl

# %%
x = np.arange(0, 4, 0.2)
y = np.exp(-x)
e1 = 0.1 * np.abs(np.random.rand(len(y)))
e2 = 0.05*np.abs(np.random.rand(len(y)))
plt.errorbar(x, y, yerr=[e1, e2], fmt='o-.', ecolor='#C63D0F')
plt.show()

# %%
theta = np.arange(0, 2, 1./180.)*np.pi
plt.polar(theta, np.cos(8*theta), '-', color='#118C4E')
plt.show()

# %%
plt.annotate('this is the\norigin', xy=(90, 0.01), xytext=(270, 0.4),
             arrowprops=dict(facecolor='#FF9009',
                             shrink=0.05), 
             color='#FF9009')
plt.show()

# %% [markdown]
# # OO fashion

# %%
figure = plt.figure()
axes = figure.add_subplot(1,1,1)
x = np.arange(1, 10, 0.01)
y = np.random.randn(len(x))*10
l, = plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,...">

# %%
l.set_color('#DF3D82')

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
l, = plt.plot([1,2,3])
l.set_color('red')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
l2, = axes.plot([1,4,2,10])

# %%
l2.set_color('yellow')

# %%
ax3 = ax2.twinx()
l3, = ax3.plot([100,10], 'b:')

# %%
ax3.set_ylabel('right side')
ax2.set_ylabel('left side')

# %%
old_font = plt.rcParams['font.size']
plt.rcParams['font.size'] = 11
fig = plt.figure()
ax1 = fig.add_subplot(311)
ax1.plot([1, 2])
ax2 = fig.add_subplot(312, sharex=ax1, sharey=ax1)
ax2.plot([1, 20])
ax3 = fig.add_subplot(313, sharex=ax1, sharey=ax2)
ax3.plot([1,200])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
from dateutil import parser as dateparser
import datetime
import pandas as pd

# %%
dateparser.parse(u'2002, 04, 01')
# Out:
# datetime.datetime(2002, 4, 1, 0, 0)

# %%
date1_s = '2016-05-01'
date2_s = '2016-08-01'
date1, date2 = [dateparser.parse(d) for d in [date1_s, date2_s]]
delta_date = datetime.timedelta(days=3)
date_range=mpl.dates.drange(date1, date2, delta_date)
y = np.random.randn(len(date_range))
fig_time = plt.figure()
ax = fig_time.add_subplot(111)
ax.plot_date(date_range, y, 'or:')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
def zh_dateformatter(d, pos=None):
    date = mpl.dates.num2date(d)
    timestamp = pd.Timestamp(date)
    y = timestamp.year
    m = timestamp.month
    d = timestamp.day
    return '{0}/{1}/{2}'.format(y%100, m, d)

# %%
print zh_dateformatter(mpl.dates.date2num(dateparser.parse('2012-01-02')), None)
# Out:
# 12/1/2

# %%
ax.xaxis.set_major_formatter(mpl.ticker.FuncFormatter(zh_dateformatter))
ax.xaxis.set_major_locator(mpl.dates.DayLocator(interval=10))
ax.xaxis.set_minor_locator(mpl.dates.HourLocator(interval=48))
plt.show()

# %%
fig_time.autofmt_xdate(bottom=0.18)
plt.show()

# %%
fig.subplots_adjust(left=0.25)

# %%
t = ax.set_xlabel('date _ for fun')

# %%
plt.setp(t, fontsize=20, color='#DF3D82')
plt.show()

# %%
for i in ax.get_xticklabels():
    print i
# Out:
# Text(736093,0,u'May 09 2016')
# Text(736107,0,u'May 23 2016')
# Text(736121,0,u'Jun 06 2016')
# Text(736135,0,u'Jun 20 2016')
# Text(736149,0,u'Jul 04 2016')
# Text(736163,0,u'Jul 18 2016')

# %%
for i, label in enumerate(ax.get_xticklabels()):
    label.set_fontsize(i+5)

# %%
ax.text(mpl.dates.date2num(dateparser.parse('July, 18, 2016')), 0.0, r'this is $\omega$')

# %%
ax.set_title(r'$\mu>\alpha$')

# %%
fig_contour = plt.figure()
ax = fig_contour.add_subplot(211)
x = np.random.randn(50) + 2
y = np.random.randn(50) + 10
X, Y = np.meshgrid(x, y)
Z = X**2/4 + Y**2/16 - 5
contour_p = ax.contourf(Z)
plt.clabel(contour_p)
plt.colorbar(contour_p)
ax.set_aspect('equal')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
ax2 = fig_contour.add_subplot(212)
img = ax2.imshow(Z)
plt.colorbar(img)
plt.show()

# %%
def get_grid(x:tuple, y:tuple) -> tuple:
    return x
# Out:
#   File "<ipython-input-2-a033831bc225>", line 1
#     def get_grid(x:tuple, y:tuple) -> tuple:
#                   ^
# SyntaxError: invalid syntax
